# %%
ans=[]
f=open('qualifying.txt')
all=f.readlines()
f.close()
idx=0
while idx<len(all):
    x=all[idx]
    mv_id=x[:x.find(':')]
    if int(mv_id)<4500:
        ans.append(all[idx])
    idx+=1
    while idx<len(all) and all[idx].find(':')==-1:
        if int(mv_id)<4500:
            ans.append(all[idx])
        idx+=1

# %%
ans=[]
f=open(f'combined_data_1.txt')
all=f.readlines()
f.close()
idx=0
while idx<len(all):
    x=all[idx]
    mv_id=x[:x.find(':')]
    idx+=1
    while idx<len(all) and all[idx].find(':')==-1:
        ans.append(mv_id+','+all[idx])
        idx+=1

# %%
f=open(f'combined_data_1.txt')
all=f.readlines()
f.close()
all
f=open(f'new_combined_data_1.txt','w')

# %%
all.index('500:\n')
# Out:
# 2798671

# %%
f=open(f'new_combined_data_1.txt','w')
f.writelines(all)
f.close()

# %%
all=all[:2798671]

# %%
f=open('x.csv','w')
f.writelines(ans)
f.close()
import pandas as pd
A=pd.read_csv('x.csv',header=None)
A.columns='movieId,userId,rating,timestamp'.split(',')
A=A['userId,movieId,rating,timestamp'.split(',')]

# %%
A[:5]
# Out:
#     userId  movieId  rating   timestamp
# 0  1488844        1       3  2005-09-06
# 1   822109        1       5  2005-05-13
# 2   885013        1       4  2005-10-19
# 3    30878        1       4  2005-12-26
# 4   823519        1       3  2004-05-03

# %%
A=A[A['movieId']<500]

# %%
A=A.set_index('userId')

# %%
A.to_csv?

# %%
A[A['m.to_csv

# %%
A[A['movieId']<500].to_csv

# %%
A.to_csv('xx.csv')

# %%
#from surprise import SVD
from surprise import Dataset
from surprise import Reader
from surprise import BaselineOnly, KNNBasic, NormalPredictor
from surprise import accuracy
from surprise.model_selection import KFold
#import pandas as pd

# 数据读取
reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1)
data = Dataset.load_from_file('./xx.csv', reader=reader)
train_set = data.build_full_trainset()

# ALS优化
bsl_options = {'method': 'als','n_epochs': 5,'reg_u': 12,'reg_i': 5}
# SGD优化
#bsl_options = {'method': 'sgd','n_epochs': 5}
algo = BaselineOnly(bsl_options=bsl_options)
#algo = BaselineOnly()
#algo = NormalPredictor()

# 定义K折交叉验证迭代器，K=3
kf = KFold(n_splits=3)
for trainset, testset in kf.split(data):
    # 训练并预测
    algo.fit(trainset)
    predictions = algo.test(testset)
    # 计算RMSE
    accuracy.rmse(predictions, verbose=True)

uid = str(196)
iid = str(302)
# 输出uid对iid的预测结果
pred = algo.predict(uid, iid, r_ui=4, verbose=True)
# Out:
# Estimating biases using als...
# RMSE: 0.9764
# Estimating biases using als...
# RMSE: 0.9797
# Estimating biases using als...
# RMSE: 0.9786
# user: 196        item: 302        r_ui = 4.00   est = 2.91   {'was_impossible': False}

# %%
algo.predict(uid, iid, r_ui=4).est
# Out:
# 3.087705836154005

# %%
# Out:
# user: 1711859    item: 302        r_ui = 4.00   est = 3.09   {'was_impossible': False}

# %%
ans=[]
f=open('qualifying.txt')
all=f.readlines()
f.close()
idx=0
while idx<len(all):
    x=all[idx]
    mv_id=x[:x.find(':')]
    if int(mv_id)<500:
        ans.append(all[idx])
    idx+=1
    while idx<len(all) and all[idx].find(':')==-1:
        u=all[idx]
        user_id=u[:u.find(',')]
        ans.append(all[idx])
        idx+=1

# %%
f=open('new_qualifying.txt','w')
f.writelines(ans)
f.close()

# %%
algo.predict?

# %%
import pandas as pd
A=pd.read_csv('xx.csv')

# %%
U=set(A['userId'].values)

# %%
U
# Out:
# {1048579,
#  6,
#  7,
#  1048586,
#  2097163,
#  10,
#  1048594,
#  1048600,
#  25,
#  2097185,
#  2097186,
#  33,
#  1048612,
#  42,
#  1048619,
#  1048624,
#  2097200,
#  1048629,
#  1048633,
#  2097210,
#  59,
#  1048635,
#  2097213,
#  79,
#  2097232,
#  83,
#  2097236,
#  1048660,
#  87,
#  2097242,
#  2097244,
#  1048668,
#  94,
#  2097249,
#  97,
#  2097252,
#  2097253,
#  2097254,
#  2097256,
#  2097264,
#  2097267,
#  116,
#  1048699,
#  1048700,
#  2097277,
#  2097275,
#  126,
#  2097276,
#  131,
#  1048708,
#  134,
#  1048711,
#  2097287,
#  2097286,
#  1048712,
#  1048715,
#  142,
#  2097296,
#  1048728,
#  158,
#  1048735,
#  164,
#  168,
#  169,
#  1048749,
#  2097327,
#  177,
#  178,
#  1048756,
#  183,
#  1048763,
#  2097339,
#  188,
#  1048766,
#  192,
#  2097345,
#  195,
#  2097347,
#  199,
#  201,
#  2097353,
#  2097359,
#  2097364,
#  1048789,
#  1048793,
#  2097373,
#  2097381,
#  231,
#  1048810,
#  2097388,
#  1048813,
#  1048812,
#  2097392,
#  1048817,
# ...
